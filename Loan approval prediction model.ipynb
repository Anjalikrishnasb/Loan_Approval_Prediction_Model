# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#To suppress all the warnings
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
df=pd.read_csv("C:\\Users\\ANJALI\\Downloads\\train_u6lujuX_CVtuZ9i.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#checking outliers
plt.figure(figsize=(12,8))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
#fill the null values of numerical data type(here we choose median,bcz median gives the least value)
#if there is outliers,we can use median,otherwise use mean
df[ 'LoanAmount']=df['LoanAmount'].fillna(df[ 'LoanAmount'].median())
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df[ 'Credit_History']=df['Credit_History'].fillna(df[ 'Credit_History'].mean())

# %%
#fill the null values of categorical data type
df[ 'Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df[ 'Married']=df['Married'].fillna(df[ 'Married'].mode()[0])
df[ 'Dependents']=df['Dependents'].fillna(df[ 'Dependents'].mode()[0])
df[ 'Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#Data visualization

# %%
print('Number of people who took loan by Gender')
print(df['Gender'].value_counts())
# Out:
# Number of people who took loan by Gender
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
print('Number of people who took loan by Marriedr')
print(df['Married'].value_counts())
# Out:
# Number of people who took loan by Marriedr
# Married
# Yes    401
# No     213
# Name: count, dtype: int64

# %%
sns.countplot(x='Married',data=df)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
print('Number of people who took loan by Education')
print(df['Education'].value_counts())
# Out:
# Number of people who took loan by Education
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
sns.countplot(x='Education',data=df)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
df1=df[['LoanAmount','Loan_Amount_Term','Credit_History','ApplicantIncome','CoapplicantIncome']]
corr=df1.corr()
corr
# Out:
#                    LoanAmount  Loan_Amount_Term  Credit_History  \
# LoanAmount           1.000000          0.039235       -0.007031
# Loan_Amount_Term     0.039235          1.000000        0.001395
# Credit_History      -0.007031          0.001395        1.000000
# ApplicantIncome      0.565181         -0.045242       -0.014477
# CoapplicantIncome    0.189218         -0.059675       -0.001665
#
#                    ApplicantIncome  CoapplicantIncome
# LoanAmount                0.565181           0.189218
# Loan_Amount_Term         -0.045242          -0.059675
# Credit_History           -0.014477          -0.001665
# ApplicantIncome           1.000000          -0.116605
# CoapplicantIncome        -0.116605           1.000000

# %%
sns.heatmap(corr,annot=True,cmap='BuPu')
# Out:
# <Axes: >

# %%
df.drop('Loan_ID',axis=1,inplace=True)

# %%
#Feature_engineering

# %%
#create a new feature
df['Total_Income']=df['ApplicantIncome']+df['CoapplicantIncome']
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  Total_Income
# 0         Urban           Y        5849.0
# ...

# %%
#apply log transformation,which is used for many purpose like normalization,residual analysis and homogenization.
df['ApplicantIncome_log']=np.log(df['ApplicantIncome']+1)

# %%
sns.distplot(df['ApplicantIncome_log'])
# Out:
# <Axes: xlabel='ApplicantIncome_log', ylabel='Density'>

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  Total_Income  ApplicantIncome_log
# ...

# %%
df['LoanAmount_log']=np.log(df['LoanAmount']+1)
sns.distplot(df['LoanAmount_log'])
# Out:
# <Axes: xlabel='LoanAmount_log', ylabel='Density'>

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  Total_Income  ApplicantIncome_log  LoanAmount_log
# ...

# %%
#This process is called Normalization
df['Loan_Amount_Term_log']=np.log(df['Loan_Amount_Term']+1)
sns.distplot(df['Loan_Amount_Term_log'])
# Out:
# <Axes: xlabel='Loan_Amount_Term_log', ylabel='Density'>

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  Total_Income  ApplicantIncome_log  \
# ...

# %%
df['Total_Income_log']=np.log(df['Total_Income']+1)
sns.distplot(df['Total_Income_log'])
# Out:
# <Axes: xlabel='Total_Income_log', ylabel='Density'>

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  Total_Income  ApplicantIncome_log  \
# ...

# %%
#Drop unnecessary columns
col=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_Income']
df.drop(columns=col,axis=1)
# Out:
#      Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0      Male      No          0      Graduate            No             1.0
# 1      Male     Yes          1      Graduate            No             1.0
# 2      Male     Yes          0      Graduate           Yes             1.0
# 3      Male     Yes          0  Not Graduate            No             1.0
# 4      Male      No          0      Graduate            No             1.0
# ..      ...     ...        ...           ...           ...             ...
# 609  Female      No          0      Graduate            No             1.0
# 610    Male     Yes         3+      Graduate            No             1.0
# 611    Male     Yes          1      Graduate            No             1.0
# 612    Male     Yes          2      Graduate            No             1.0
# 613  Female      No          0      Graduate           Yes             0.0
#
# ...

# %%
#Encoding techniques:label,one hot encoding

# %%
from sklearn.preprocessing import LabelEncoder
cols=['Gender','Married','Education','Dependents','Self_Employed','Property_Area','Loan_Status']
le=LabelEncoder()
for col in cols:
    df[col]=le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status  Total_Income  ApplicantIncome_log  \
# ...

# %%
df.dtypes
# Out:
# Gender                    int32
# Married                   int32
# Dependents                int32
# Education                 int32
# Self_Employed             int32
# ApplicantIncome           int64
# CoapplicantIncome       float64
# LoanAmount              float64
# Loan_Amount_Term        float64
# Credit_History          float64
# Property_Area             int32
# Loan_Status               int32
# Total_Income            float64
# ApplicantIncome_log     float64
# LoanAmount_log          float64
# Loan_Amount_Term_log    float64
# Total_Income_log        float64
# dtype: object

# %%
#creating independent features and dependent features
#Here loan_status is the dependent variable,all other variables are independent.
#split the variables into dependent and independent

x=df.drop('Loan_Status',axis=1)
y=df['Loan_Status']

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
#Logistic Regression
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred_model=model.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy=accuracy_score(y_test,y_pred_model)
accuracy
# Out:
# 0.8292682926829268

# %%
confusion_matrix=confusion_matrix(y_test,y_pred_model)
confusion_matrix
# Out:
# array([[17, 16],
#        [ 5, 85]], dtype=int64)

# %%
score=cross_val_score(model,x,y,cv=5)
score
# Out:
# array([0.81300813, 0.77235772, 0.7804878 , 0.82113821, 0.81147541])

# %%
np.mean(score)*100
# Out:
# 79.9693455950953

# %%
#Decision tree
model2=DecisionTreeClassifier()
model2.fit(x_train,y_train)
y_pred_model2=model2.predict(x_test)
accuracy=accuracy_score(y_test,y_pred_model2)
accuracy
# Out:
# 0.7642276422764228

# %%
score=cross_val_score(model2,x,y,cv=5)
print("cross value of decision_tree")
np.mean(score)*100
# Out:
# cross value of decision_tree
# 73.61455417832866

# %%
#Random forest
model3=RandomForestClassifier()
model3.fit(x_train,y_train)
y_pred_model3=model3.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy=accuracy_score(y_test,y_pred_model3)
accuracy
# Out:
# 0.8292682926829268

# %%
score=cross_val_score(model3,x,y,cv=5)
print("cross value of random forest is")
np.mean(score)*100
# Out:
# cross value of random forest is
# 78.83246701319473

# %%
model4=KNeighborsClassifier(n_neighbors=3)
model4.fit(x_train,y_train)
y_pred=model4.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.5934959349593496

# %%
score=cross_val_score(model4,x,y,cv=5)
print("cross value of k neighbors")
np.mean(score)*100
# Out:
# cross value of k neighbors
# 59.29628148740505

# %%
from sklearn.metrics import classification_report
def generate_classification_report(model_name,y_test,y_pred):
    report=classification_report(y_test,y_pred)
    print(f"classification report for {model_name}:\n{report}\n")
    
generate_classification_report(model,y_test,y_pred_model)
generate_classification_report(model2,y_test,y_pred_model2)
generate_classification_report(model3,y_test,y_pred_model3)
generate_classification_report(model4,y_test,y_pred)
# Out:
# classification report for LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.77      0.52      0.62        33
#            1       0.84      0.94      0.89        90
#
#     accuracy                           0.83       123
#    macro avg       0.81      0.73      0.75       123
# weighted avg       0.82      0.83      0.82       123
#
#
# classification report for DecisionTreeClassifier():
#               precision    recall  f1-score   support
#
#            0       0.55      0.64      0.59        33
#            1       0.86      0.81      0.83        90
#
#     accuracy                           0.76       123
#    macro avg       0.71      0.72      0.71       123
# weighted avg       0.78      0.76      0.77       123
#
#
# classification report for RandomForestClassifier():
#               precision    recall  f1-score   support
#
#            0       0.75      0.55      0.63        33
# ...

# %%
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %%
#to solve the probelm of imbalanced dataset

# %%
pip install -U imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#oversampling,it's mainly used to addres the issue of class imbalance in datasets.
from imblearn.over_sampling import RandomOverSampler

# %%
oversample=RandomOverSampler(random_state=42)
x_resampled,y_resampled=oversample.fit_resample(x,y)
df_resampled=pd.concat([pd.DataFrame(x_resampled,columns=x.columns),pd.Series(y_resampled,name="Loan_Status")],axis=1)

# %%
x_resampled
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 839       1        1           3          1              0             3992
# 840       1        1           1          0              0             1880
# 841       1        1           1          0              0             2787
# 842       1        1           2          1              0             2889
# 843       1        0           0          0              0             4166
#
# ...

# %%
y_resampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 839    0
# 840    0
# 841    0
# 842    0
# 843    0
# Name: Loan_Status, Length: 844, dtype: int32

# %%
y_resampled.value_counts()#for balancing
# Out:
# Loan_Status
# 1    422
# 0    422
# Name: count, dtype: int64

# %%
x_resampled_train,x_resampled_test,y_resampled_train,y_resampled_test=train_test_split(x_resampled,y_resampled,test_size=0.2,random_state=42)

# %%
#logistic
model=LogisticRegression()
model.fit(x_resampled_train,y_resampled_train)
y_pred_model=model.predict(x_resampled_test)
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy=accuracy_score(y_resampled_test,y_pred_model)
accuracy
# Out:
# 0.7159763313609467

# %%
#decision tree
model2=DecisionTreeClassifier()
model2.fit(x_resampled_train,y_resampled_train)
y_pred_model2=model2.predict(x_resampled_test)
accuracy=accuracy_score(y_resampled_test,y_pred_model2)
accuracy
# Out:
# 0.8284023668639053

# %%
#Random forest
model3=RandomForestClassifier()
model3.fit(x_resampled_train,y_resampled_train)
y_pred_model3=model3.predict(x_resampled_test)
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy=accuracy_score(y_resampled_test,y_pred_model3)
accuracy
# Out:
# 0.9053254437869822

# %%
#KNeighbors
model4=KNeighborsClassifier(n_neighbors=3)
model4.fit(x_resampled_train,y_resampled_train)
y_pred=model4.predict(x_resampled_test)
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy=accuracy_score(y_resampled_test,y_pred)
accuracy
# Out:
# 0.6686390532544378

# %%
from sklearn.metrics import classification_report
def generate_classification_report(model_name,y_test,y_pred):
    report=classification_report(y_test,y_pred)
    print(f"classification report for {model_name}:\n{report}\n")
    
generate_classification_report(model,y_resampled_test,y_pred_model)
generate_classification_report(model2,y_resampled_test,y_pred_model2)
generate_classification_report(model3,y_resampled_test,y_pred_model3)
generate_classification_report(model4,y_resampled_test,y_pred)
# Out:
# classification report for LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.84      0.61      0.70        94
#            1       0.63      0.85      0.73        75
#
#     accuracy                           0.72       169
#    macro avg       0.74      0.73      0.72       169
# weighted avg       0.75      0.72      0.71       169
#
#
# classification report for DecisionTreeClassifier():
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.86        94
#            1       0.87      0.72      0.79        75
#
#     accuracy                           0.83       169
#    macro avg       0.84      0.82      0.82       169
# weighted avg       0.83      0.83      0.83       169
#
#
# classification report for RandomForestClassifier():
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91        94
# ...
